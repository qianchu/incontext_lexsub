# %%
from allennlp.modules.elmo import Elmo, batch_to_ids
import sys
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
####read evaluation data
def read_gold_candidates(gold_candis_f):
    ## read in substitutes apart from MWE
    target_w2candidates={}
    with open (gold_candis_f) as f:
        for line in f:
            line=line.strip()
            target_w,candidates=line.split('::')
            candidates=[candi for candi in candidates.split(';') if ' ' not in candi]
            target_w2candidates[target_w]=candidates
    
    return target_w2candidates


def read_eval_data(data_f):
    sents=[]
    pos_lst=[]
    target_ws=[]
    with open (data_f,encoding='utf-8',errors='replace') as f:
        try:
            for line in f:
                line=line.strip().split('\t')
                target_ws.append(line[0]+' '+line[1])
                pos_lst.append(int(line[2]))
                sent_w_lst=line[3].split()
                if sent_w_lst[int(line[2])]!=line[0].split('.')[0]:
                    print ('warning: position {2}, target_w:{0}:{1}'.format(line[0],sent_w_lst[int(line[2])],line[2]))
                sents.append(sent_w_lst)
        except UnicodeDecodeError as e:
            print (line)
            print (e)
    return sents,pos_lst,target_ws

###### elmo word representation
def w2elmo_type_batch(w_lst,batchsize):
    '''
    w_lst=['apple','orange']
    '''
    candidates_all=[]
    candi2index={}
    index=0
    for candi in w_lst:
            if candi not in candidates_all:
                candidates_all.append([candi])
                candi2index[candi]=index
                index+=1

    candis2elmo=w2elmo_token_batch(candidates_all,batchsize,[0]*len(candidates_all))
    return candis2elmo,candi2index,candidates_all

def w2elmo_token_batch(sent_lst,batchsize,pos_lst=None):
    '''
    sent_lst=[['there','is','an','apple','.'],['there','is','an','apple','.']]
    pos_lst=[2,3] the position list
    '''
    character_ids_all = batch_to_ids(sent_lst)
    context_reps=[]
    for i in range(int(len(sent_lst)/batchsize)+1):
        print (i)
        start=i*batchsize
        end=(i+1)*batchsize
        if start>=len(sent_lst):
            break
        if end > len(sent_lst):
            end=len(sent_lst)
        
        sentences=sent_lst[start:end]
        character_ids=character_ids_all[start:end]
        embeddings = elmo(character_ids)
        
        if pos_lst!=None:
            pos=pos_lst[start:end]
            context_reps.append(embeddings['elmo_representations'][0].detach().numpy()[np.arange(len(sentences)),np.array(pos)])
        else:
            context_reps.append(embeddings['elmo_representations'][0].detach().numpy())

    context_reps=np.concatenate(context_reps,axis=0)
    return context_reps
        
###### candidates ranking and ouput
def candidate_ranking_out(output_f,words2elmo_token,target_ws,target_w2candidates,candi2index,candis2elmo):
      with open (output_f,'w') as f:
        for i in range(len(words2elmo_token)):
            w2elmo_token=words2elmo_token[i]
            target_w=target_ws[i]
            try:
                candidates=target_w2candidates['.'.join(target_w.split()[0].split('.')[:2])]
                candis_cos=[]
                for candi in candidates:
                        candi_type=candis2elmo[candi2index[candi]]
                        cos=cosine_similarity([w2elmo_token],[candi_type])[0][0]
                        candis_cos.append('{0} {1}'.format(candi,cos))

                candis_cos=sorted(candis_cos,key=lambda x:x.split()[1],reverse=True)
                candis_cos='\t'.join(candis_cos)
                out_line='RANKED\t{0}\t{1}\n'.format(target_w,candis_cos)
                f.write(out_line)
            except KeyError as e:
                print (e)
                continue

# %%
if __name__=="__main__":
    
    #elmo parameters
    elmo_options_file = "https://s3-us-west-2.amazonaws.com/allennlp/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_options.json"
    elmo_weight_file = "https://s3-us-west-2.amazonaws.com/allennlp/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5"

    if sys.argv[0]=='/usr/local/lib/python3.6/site-packages/ipykernel_launcher.py':
        model='elmo'
        data_f='/home/incontext_lexsub/eval/lexsub_en/datasets/lst_all.preprocessed'
        gold_candis_f='/home/incontext_lexsub/eval/lexsub_en/datasets/lst.gold.candidates'
        
        
    else:
        print ('python lexsub_eval.py [model] [data_f] [gold_candis_f]')
        model=sys.argv[1]
        data_f=sys.argv[2]
        gold_candis_f=sys.argv[3]
    
    output_f=data_f.split('/')[-1]+'.ranked'
    
   
    # 1. read in model
    if model=='elmo':
        elmo = Elmo(elmo_options_file, elmo_weight_file, 1, dropout=0)
    else:
        raise NotImplementedError


    # 2. read in gold substitutes
    target_w2candidates=read_gold_candidates(gold_candis_f)
    # 3. evaluate on the data:
    sents,pos_lst,target_ws=read_eval_data(data_f)

    # 3.1. candi2elmo type word representation
    candidates_all=[w for lst in target_w2candidates.values() for w in lst]
    candis2elmo,candi2index,candidates_all=w2elmo_type_batch(candidates_all,1000)


    # 3.2. token level context representations
    words2elmo_token=w2elmo_token_batch(sents,100,pos_lst)

    # 3.3. candidate ranking
    candidate_ranking_out(output_f,words2elmo_token,target_ws,target_w2candidates,candi2index,candis2elmo)
#     with open (output_f,'w') as f:
#         for i in range(len(words2elmo_token)):
#             w2elmo_token=words2elmo_token[i]
#             target_w=target_ws[i]
#             candidates=target_w2candidates[target_w.split()[0]]
#             candis_cos=[]
#             for candi in candidates:
#                 candi_type=candis2elmo[candi2index[candi]]
#                 cos=cosine_similarity([w2elmo_token],[candi_type])[0][0]
#                 candis_cos.append('{0} {1}'.format(candi,cos))
#             candis_cos=sorted(candis_cos,key=lambda x:x.split()[1],reverse=True)
#             candis_cos='\t'.join(candis_cos)
#             out_line='RANKED\t{0}\t{1}\n'.format(target_w,candis_cos)
#             f.write(out_line)
# Out:
# warning: position 22, target_w:bright.a:brighter
# warning: position 30, target_w:bright.a:brightest
# warning: position 37, target_w:bright.a:brightest
# warning: position 7, target_w:film.n:films
# warning: position 25, target_w:film.n:films
# warning: position 7, target_w:film.n:films
# warning: position 12, target_w:take.v:taking
# warning: position 14, target_w:take.v:took
# warning: position 16, target_w:take.v:takes
# warning: position 2, target_w:take.v:took
# warning: position 15, target_w:take.v:took
# warning: position 2, target_w:bar.n:bars
# warning: position 24, target_w:bar.n:bars
# warning: position 19, target_w:find.v:found
# warning: position 7, target_w:find.v:found
# warning: position 9, target_w:find.v:found
# warning: position 2, target_w:find.v:finds
# warning: position 24, target_w:find.v:found
# warning: position 18, target_w:fix.v:fixing
# warning: position 28, target_w:fix.v:fixed
# warning: position 23, target_w:fix.v:fixed
# warning: position 11, target_w:fix.v:fixed
# warning: position 18, target_w:fix.v:fixed
# warning: position 27, target_w:manage.v:managed
# warning: position 31, target_w:manage.v:managed
# warning: position 18, target_w:manage.v:managing
# warning: position 5, target_w:manage.v:managed
# warning: position 4, target_w:manage.v:managed
# warning: position 4, target_w:neat.a:neatest
# warning: position 18, target_w:neat.a:neater
# warning: position 14, target_w:rich.a:richer
# warning: position 10, target_w:stand.n.v:stands
# warning: position 2, target_w:stand.n.v:stands
# warning: position 13, target_w:stand.n.v:stands
# warning: position 42, target_w:stand.n:stands
# warning: position 23, target_w:can.n:cans
# warning: position 15, target_w:can.n:cans
# warning: position 9, target_w:can.n:cans
# warning: position 6, target_w:can.n:cans
# warning: position 9, target_w:can.n:cans
# warning: position 7, target_w:can.n:cans
# warning: position 11, target_w:can.n:cans
# warning: position 12, target_w:examination.n:examinations
# warning: position 1, target_w:fear.v:feared
# warning: position 5, target_w:fear.v:fearing
# warning: position 1, target_w:fear.v:fears
# warning: position 2, target_w:fear.v:fears
# warning: position 15, target_w:fear.v:feared
# warning: position 33, target_w:fear.v:feared
# warning: position 9, target_w:fear.v:feared
# warning: position 9, target_w:fear.v:feared
# warning: position 8, target_w:forget.v:forgotten
# warning: position 28, target_w:forget.v:forgot
# warning: position 30, target_w:forget.v:forgotten
# warning: position 11, target_w:forget.v:forgotten
# warning: position 8, target_w:forget.v:forgot
# warning: position 1, target_w:gall.n:galls
# warning: position 0, target_w:gall.n:galls
# warning: position 46, target_w:lie.v:lies
# warning: position 15, target_w:lie.v:lay
# warning: position 1, target_w:lie.v:lies
# warning: position 25, target_w:lie.v:lay
# warning: position 3, target_w:lie.v:lying
# warning: position 6, target_w:lie.v:lying
# warning: position 22, target_w:lie.v:lying
# warning: position 10, target_w:run.v:running
# warning: position 21, target_w:run.v:ran
# warning: position 25, target_w:run.v:running
# warning: position 7, target_w:run.v:ran
# warning: position 9, target_w:run.v:runs
# warning: position 17, target_w:run.v:runs
# warning: position 24, target_w:tell.v:told
# warning: position 13, target_w:tell.v:told
# warning: position 1, target_w:tell.v:told
# warning: position 5, target_w:tell.v:told
# warning: position 9, target_w:tell.v:tells
# warning: position 1, target_w:think.v:thinks
# warning: position 13, target_w:think.v:thought
# warning: position 18, target_w:think.v:thought
# warning: position 2, target_w:wind.n:winds
# warning: position 59, target_w:wind.n:winds
# warning: position 3, target_w:charge.v:charged
# warning: position 14, target_w:charge.v:charges
# warning: position 6, target_w:charge.v:charged
# warning: position 13, target_w:charge.v:charged
# warning: position 34, target_w:charge.v:charged
# warning: position 6, target_w:charge.v:charged
# warning: position 4, target_w:charge.v:charged
# warning: position 5, target_w:clean.v:cleaning
# warning: position 9, target_w:clean.v:cleaning
# warning: position 18, target_w:coach.n:coaches
# warning: position 15, target_w:coach.n:coaches
# warning: position 2, target_w:coach.n:coaches
# warning: position 23, target_w:heap.n:heaps
# warning: position 7, target_w:heap.n:heaps
# warning: position 1, target_w:pulse.n:pulses
# warning: position 13, target_w:pulse.n:pulses
# warning: position 5, target_w:pulse.n:pulses
# warning: position 39, target_w:pulse.n:pulses
# warning: position 24, target_w:pulse.n:pulses
# warning: position 11, target_w:pulse.n:pulses
# warning: position 11, target_w:return.v:returned
# warning: position 2, target_w:return.v:returned
# warning: position 17, target_w:return.v:returning
# warning: position 4, target_w:return.v:returning
# warning: position 12, target_w:return.v:returned
# warning: position 8, target_w:return.v:returns
# warning: position 3, target_w:shed.v:sheds
# warning: position 6, target_w:shed.v:sheds
# warning: position 17, target_w:shed.v:shedding
# warning: position 6, target_w:way.n:ways
# warning: position 24, target_w:way.n:ways
# warning: position 15, target_w:bug.n:bugs
# warning: position 17, target_w:bug.n:bugs
# warning: position 26, target_w:bug.n:bugs
# warning: position 12, target_w:bug.n:bugs
# warning: position 2, target_w:bull.n:bulls
# warning: position 4, target_w:girl.n:girls
# warning: position 8, target_w:girl.n:girls
# warning: position 40, target_w:girl.n:girls
# warning: position 19, target_w:heavy.a:heaviest
# warning: position 5, target_w:mass.n:masses
# warning: position 8, target_w:mass.n:masses
# warning: position 27, target_w:mass.n:masses
# warning: position 7, target_w:mass.n:masses
# warning: position 19, target_w:match.n:matches
# warning: position 22, target_w:mood.n:moods
# warning: position 33, target_w:mood.n:moods
# warning: position 25, target_w:mood.n:moods
# warning: position 24, target_w:mood.n:moods
# warning: position 3, target_w:post.n:posts
# warning: position 4, target_w:post.n:posts
# warning: position 8, target_w:post.n:posts
# warning: position 6, target_w:pound.n:pounds
# warning: position 25, target_w:pound.n:pounds
# warning: position 19, target_w:remainder.n:remainders
# warning: position 7, target_w:rude.a:ruder
# warning: position 5, target_w:saint.n:saints
# warning: position 8, target_w:strain.n:strains
# warning: position 3, target_w:strain.n:strains
# warning: position 12, target_w:strain.n:strains
# warning: position 13, target_w:strain.n:strains
# warning: position 5, target_w:time.n:times
# warning: position 2, target_w:time.n:times
# warning: position 13, target_w:time.n:times
# warning: position 27, target_w:time.n:times
# warning: position 22, target_w:yard.n:yards
# warning: position 22, target_w:yard.n:yards
# warning: position 41, target_w:yard.n:yards
# warning: position 17, target_w:check.v:checking
# warning: position 6, target_w:check.v:checked
# warning: position 2, target_w:check.v:checked
# warning: position 26, target_w:clear.v:cleared
# warning: position 38, target_w:clear.v:clears
# warning: position 32, target_w:clear.v:cleared
# warning: position 5, target_w:clear.v:clearing
# warning: position 14, target_w:clear.v:clears
# warning: position 10, target_w:clear.v:cleared
# warning: position 3, target_w:clear.v:cleared
# warning: position 9, target_w:come.v:coming
# warning: position 2, target_w:come.v:comes
# warning: position 10, target_w:come.v:coming
# warning: position 1, target_w:come.v:came
# warning: position 6, target_w:come.v:comes
# warning: position 2, target_w:cry.v:cries
# warning: position 10, target_w:cry.v:cried
# warning: position 26, target_w:cry.v:crying
# warning: position 19, target_w:cry.v:cries
# warning: position 7, target_w:cry.v:crying
# warning: position 31, target_w:dismiss.v:dismissed
# warning: position 10, target_w:dismiss.v:dismissed
# warning: position 14, target_w:dismiss.v:dismissed
# warning: position 6, target_w:dismiss.v:dismissed
# warning: position 7, target_w:dismiss.v:dismisses
# warning: position 24, target_w:dismiss.v:dismissed
# warning: position 5, target_w:draw.v:drawn
# warning: position 6, target_w:draw.v:drawing
# warning: position 3, target_w:draw.v:drawn
# warning: position 8, target_w:draw.v:drawing
# warning: position 30, target_w:draw.v:drawn
# warning: position 15, target_w:draw.v:drawn
# warning: position 11, target_w:draw.v:drawn
# warning: position 2, target_w:go.v:gone
# warning: position 13, target_w:go.v:went
# warning: position 17, target_w:go.v:going
# warning: position 16, target_w:go.v:going
# warning: position 20, target_w:go.v:going
# warning: position 16, target_w:let.v:letting
# warning: position 9, target_w:let.v:lets
# warning: position 15, target_w:let.v:letting
# warning: position 28, target_w:light.a:lightest
# warning: position 3, target_w:light.a:lighter
# warning: position 27, target_w:order.v:ordered
# warning: position 5, target_w:order.v:ordered
# warning: position 22, target_w:order.v:ordered
# warning: position 5, target_w:order.v:ordered
# warning: position 3, target_w:order.v:ordering
# warning: position 8, target_w:order.v:ordered
# warning: position 3, target_w:order.v:ordered
# warning: position 2, target_w:see.v:saw
# warning: position 15, target_w:skip.v:skipped
# warning: position 16, target_w:skip.v:skipping
# warning: position 8, target_w:skip.v:skipping
# warning: position 14, target_w:skip.v:skipped
# warning: position 13, target_w:skip.v:skipped
# warning: position 3, target_w:skip.v:skips
# warning: position 31, target_w:suffer.v:suffering
# warning: position 10, target_w:suffer.v:suffered
# warning: position 21, target_w:suffer.v:suffers
# warning: position 6, target_w:suffer.v:suffered
# warning: position 7, target_w:suffer.v:suffered
# warning: position 16, target_w:suffer.v:suffers
# warning: position 13, target_w:suffer.v:suffered
# warning: position 13, target_w:tap.v:tapping
# warning: position 3, target_w:tap.v:tapping
# warning: position 20, target_w:tap.v:tapping
# warning: position 27, target_w:tap.v:tapping
# warning: position 7, target_w:tap.v:tapped
# warning: position 4, target_w:tap.v:tapped
# warning: position 13, target_w:tap.v:tapped
# warning: position 3, target_w:tap.v:tapping
# warning: position 21, target_w:touch.v:touched
# warning: position 5, target_w:touch.v:touched
# warning: position 26, target_w:touch.v:touched
# warning: position 25, target_w:touch.v:touching
# warning: position 9, target_w:touch.v:touched
# warning: position 34, target_w:account.n:accounts
# warning: position 15, target_w:account.n:accounts
# warning: position 11, target_w:account.n:accounts
# warning: position 58, target_w:account.n:accounts
# warning: position 17, target_w:account.n:accounts
# warning: position 4, target_w:acquire.v:acquires
# warning: position 16, target_w:acquire.v:acquired
# warning: position 19, target_w:acquire.v:acquired
# warning: position 35, target_w:acquire.v:acquired
# warning: position 8, target_w:acquire.v:acquired
# warning: position 21, target_w:bring.v:bringing
# warning: position 44, target_w:bring.v:brought
# warning: position 44, target_w:bring.v:brought
# warning: position 7, target_w:bring.v:brought
# warning: position 1, target_w:bring.v:brought
# warning: position 0, target_w:burst.v:bursting
# warning: position 18, target_w:burst.v:bursting
# warning: position 3, target_w:burst.v:bursting
# warning: position 11, target_w:burst.v:bursting
# warning: position 4, target_w:call.v:calling
# warning: position 29, target_w:call.v:called
# warning: position 33, target_w:call.v:called
# warning: position 15, target_w:call.v:calling
# warning: position 3, target_w:call.v:called
# warning: position 1, target_w:call.v:called
# warning: position 15, target_w:call.v:called
# warning: position 5, target_w:caravan.n:caravans
# warning: position 13, target_w:caravan.n:caravans
# warning: position 21, target_w:carry.v:carried
# warning: position 4, target_w:carry.v:carried
# warning: position 23, target_w:carry.v:carried
# warning: position 15, target_w:carry.v:carrying
# warning: position 1, target_w:carry.v:carried
# warning: position 24, target_w:decline.v:declined
# warning: position 12, target_w:decline.v:declined
# warning: position 14, target_w:decline.v:declined
# warning: position 16, target_w:decline.v:declines
# warning: position 7, target_w:decline.v:declining
# warning: position 9, target_w:decline.v:declined
# warning: position 12, target_w:decline.v:declining
# warning: position 3, target_w:drop.v:dropped
# warning: position 3, target_w:drop.v:dropped
# warning: position 24, target_w:drop.v:dropped
# warning: position 8, target_w:drop.v:dropped
# warning: position 18, target_w:drop.v:dropping
# warning: position 6, target_w:easy.a:easier
# warning: position 4, target_w:easy.a:easier
# warning: position 8, target_w:easy.a:easier
# warning: position 10, target_w:endure.v:endured
# warning: position 6, target_w:endure.v:enduring
# warning: position 31, target_w:endure.v:endured
# warning: position 4, target_w:endure.v:endured
# warning: position 17, target_w:endure.v:endured
# warning: position 14, target_w:field.n:fields
# warning: position 8, target_w:field.n:fields
# warning: position 1, target_w:field.n:fields
# warning: position 9, target_w:get.v:getting
# warning: position 8, target_w:get.v:getting
# warning: position 7, target_w:get.v:getting
# warning: position 2, target_w:get.v:got
# warning: position 20, target_w:hold.v:holding
# warning: position 18, target_w:hold.v:held
# warning: position 8, target_w:hold.v:held
# warning: position 8, target_w:hold.v:held
# warning: position 9, target_w:hold.v:holding
# warning: position 4, target_w:hold.v:held
# warning: position 14, target_w:hold.v:holding
# warning: position 25, target_w:hold.v:held
# warning: position 10, target_w:hold.v:holding
# warning: position 1, target_w:investigator.n:investigators
# warning: position 33, target_w:investigator.n:investigators
# warning: position 14, target_w:investigator.n:investigators
# warning: position 20, target_w:investigator.n:investigators
# warning: position 9, target_w:investigator.n:investigators
# warning: position 1, target_w:investigator.n:investigators
# warning: position 3, target_w:investigator.n:investigators
# warning: position 6, target_w:investigator.n:investigators
# warning: position 2, target_w:letter.n:letters
# warning: position 30, target_w:letter.n:letters
# warning: position 14, target_w:letter.n:letters
# warning: position 37, target_w:letter.n:letters
# warning: position 23, target_w:letter.n:letters
# warning: position 5, target_w:letter.n:letters
# warning: position 32, target_w:letter.n:letters
# warning: position 17, target_w:make.v:made
# warning: position 8, target_w:make.v:made
# warning: position 16, target_w:make.v:made
# warning: position 2, target_w:make.v:made
# warning: position 30, target_w:make.v:made
# warning: position 17, target_w:mission.n:missions
# warning: position 11, target_w:mission.n:missions
# warning: position 45, target_w:pot.n:pots
# warning: position 8, target_w:pot.n:pots
# warning: position 7, target_w:pot.n:pots
# warning: position 24, target_w:pot.n:pots
# warning: position 9, target_w:pot.n:pots
# warning: position 5, target_w:pull.v:pulled
# warning: position 1, target_w:pull.v:pulled
# warning: position 3, target_w:pull.v:pulls
# warning: position 24, target_w:pull.v:pulled
# warning: position 6, target_w:render.v:rendered
# warning: position 17, target_w:render.v:rendered
# warning: position 19, target_w:render.v:rendering
# warning: position 37, target_w:render.v:rendered
# warning: position 18, target_w:render.v:rendering
# warning: position 2, target_w:render.v:renders
# warning: position 9, target_w:rhythm.n:rhythms
# warning: position 10, target_w:rhythm.n:rhythms
# warning: position 24, target_w:rhythm.n:rhythms
# warning: position 23, target_w:scene.n:scenes
# warning: position 14, target_w:scene.n:scenes
# warning: position 15, target_w:shade.n:shades
# warning: position 9, target_w:shade.n:shades
# warning: position 13, target_w:shade.n:shades
# warning: position 12, target_w:shade.n:shades
# warning: position 26, target_w:shade.n:shades
# warning: position 0, target_w:stiff.a:stiffer
# warning: position 2, target_w:strike.v:struck
# warning: position 13, target_w:strike.v:struck
# warning: position 42, target_w:strike.v:striking
# warning: position 4, target_w:strike.v:struck
# warning: position 7, target_w:strike.v:struck
# warning: position 1, target_w:strike.v:strikes
# warning: position 22, target_w:strike.v:strikes
# warning: position 14, target_w:strike.v:striking
# warning: position 23, target_w:suspect.v:suspected
# warning: position 0, target_w:suspect.v:suspected
# warning: position 9, target_w:suspect.v:suspects
# warning: position 19, target_w:suspect.v:suspected
# warning: position 42, target_w:tender.a:tenderest
# warning: position 9, target_w:tender.a:tenderest
# warning: position 15, target_w:test.n:tests
# warning: position 2, target_w:test.n:tests
# warning: position 20, target_w:test.n:tests
# warning: position 25, target_w:test.n:tests
# warning: position 20, target_w:throw.v:thrown
# warning: position 12, target_w:throw.v:threw
# warning: position 21, target_w:throw.v:throwing
# warning: position 11, target_w:throw.v:threw
# warning: position 8, target_w:throw.v:threw
# warning: position 11, target_w:blow.n:blows
# warning: position 25, target_w:blow.n:blows
# warning: position 9, target_w:blow.n:blows
# warning: position 20, target_w:board.n:boards
# warning: position 6, target_w:board.n:boards
# warning: position 21, target_w:cap.n:caps
# warning: position 31, target_w:cap.n:caps
# warning: position 12, target_w:change.v:changed
# warning: position 15, target_w:change.v:changing
# warning: position 0, target_w:change.v:changing
# warning: position 17, target_w:charge.n:charges
# warning: position 28, target_w:charge.n:charges
# warning: position 12, target_w:charge.n:charges
# warning: position 21, target_w:charge.n:charges
# warning: position 25, target_w:charge.n:charges
# warning: position 17, target_w:charge.n:charges
# warning: position 8, target_w:charge.n:charges
# warning: position 12, target_w:execution.n:executions
# warning: position 14, target_w:fall.v:fell
# warning: position 4, target_w:fall.v:fallen
# warning: position 9, target_w:fall.v:falling
# warning: position 29, target_w:fall.v:fell
# warning: position 4, target_w:fall.v:fell
# warning: position 38, target_w:fall.v:fell
# warning: position 7, target_w:fall.v:fallen
# warning: position 17, target_w:fall.v:fell
# warning: position 3, target_w:figure.n:figures
# warning: position 2, target_w:figure.n:figures
# warning: position 8, target_w:figure.n:figures
# warning: position 18, target_w:figure.n:figures
# warning: position 19, target_w:figure.n:figures
# warning: position 8, target_w:figure.n:figures
# warning: position 0, target_w:figure.n:figures
# warning: position 2, target_w:fire.v:fired
# warning: position 7, target_w:fire.v:fired
# warning: position 4, target_w:fire.v:fired
# warning: position 15, target_w:fire.v:fired
# warning: position 9, target_w:fire.v:fired
# warning: position 5, target_w:fire.v:fired
# warning: position 10, target_w:fire.v:fired
# warning: position 28, target_w:fire.v:fired
# warning: position 16, target_w:fire.v:fired
# warning: position 1, target_w:function.n:functions
# warning: position 0, target_w:function.n:functions
# warning: position 31, target_w:jam.n:jams
# warning: position 8, target_w:jam.n:jams
# warning: position 21, target_w:jam.n:jams
# warning: position 5, target_w:jam.n:jams
# warning: position 19, target_w:jam.n:jams
# warning: position 14, target_w:lead.n:leads
# warning: position 18, target_w:lead.n:leads
# warning: position 6, target_w:lead.n:leads
# warning: position 2, target_w:paper.n:papers
# warning: position 27, target_w:paper.n:papers
# warning: position 10, target_w:paper.n:papers
# warning: position 4, target_w:pass.v:passed
# warning: position 30, target_w:pass.v:passed
# warning: position 57, target_w:pass.v:passing
# warning: position 28, target_w:pass.v:passing
# warning: position 11, target_w:pass.v:passes
# warning: position 9, target_w:pass.v:passed
# warning: position 9, target_w:poor.a:poorer
# warning: position 3, target_w:ring.n:rings
# warning: position 8, target_w:ring.n:rings
# warning: position 19, target_w:scrap.n:scraps
# warning: position 23, target_w:scrap.n:scraps
# warning: position 26, target_w:scrap.n:scraps
# warning: position 3, target_w:shot.n:shots
# warning: position 19, target_w:shot.n:shots
# warning: position 18, target_w:shot.n:shots
# warning: position 20, target_w:shot.n:shots
# warning: position 50, target_w:shot.n:shots
# warning: position 9, target_w:show.v:shown
# warning: position 3, target_w:show.v:shown
# warning: position 0, target_w:show.v:showing
# warning: position 5, target_w:show.v:shown
# warning: position 2, target_w:show.v:shown
# warning: position 6, target_w:wind.v:winding
# warning: position 10, target_w:wind.v:winding
# warning: position 13, target_w:wind.v:winding
# warning: position 34, target_w:wind.v:winded
# warning: position 17, target_w:wind.v:wound
# warning: position 6, target_w:work.v:working
# warning: position 13, target_w:work.v:worked
# warning: position 2, target_w:work.v:worked
# warning: position 53, target_w:work.v:worked
# warning: position 11, target_w:work.v:working
# warning: position 33, target_w:work.v:working
# warning: position 7, target_w:work.v:working
# 0
# 1
# 2
# 3
# 0
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-aa63bc3fe438> in <module>()
#      38
#      39     # 3.2. token level context representations
# ---> 40     words2elmo_token=w2elmo_token_batch(sents,100,pos_lst)
#      41
#      42     # 3.3. candidate ranking
#
# <ipython-input-2-a86aa8ced9ff> in w2elmo_token_batch(sent_lst, batchsize, pos_lst)
#      68         sentences=sent_lst[start:end]
#      69         character_ids=character_ids_all[start:end]
# ---> 70         embeddings = elmo(character_ids)
#      71
#      72         if pos_lst!=None:
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/site-packages/allennlp/modules/elmo.py in forward(self, inputs, word_inputs)
#     151
#     152         # run the biLM
# --> 153         bilm_output = self._elmo_lstm(reshaped_inputs, reshaped_word_inputs)
#     154         layer_activations = bilm_output['activations']
#     155         mask_with_bos_eos = bilm_output['mask']
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/site-packages/allennlp/modules/elmo.py in forward(self, inputs, word_inputs)
#     580             mask = token_embedding['mask']
#     581             type_representation = token_embedding['token_embedding']
# --> 582         lstm_outputs = self._elmo_lstm(type_representation, mask)
#     583
#     584         # Prepare the output.  The first layer is duplicated.
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/site-packages/allennlp/modules/elmo_lstm.py in forward(self, inputs, mask)
#     121         batch_size, total_sequence_length = mask.size()
#     122         stacked_sequence_output, final_states, restoration_indices = \
# --> 123             self.sort_and_run_forward(self._lstm_forward, inputs, mask)
#     124
#     125         num_layers, num_valid, returned_timesteps, encoder_dim = stacked_sequence_output.size()
#
# /usr/local/lib/python3.6/site-packages/allennlp/modules/encoder_base.py in sort_and_run_forward(self, module, inputs, mask, hidden_state)
#     114
#     115         # Actually call the module on the sorted PackedSequence.
# --> 116         module_output, final_states = module(packed_sequence_input, initial_states)
#     117
#     118         return module_output, final_states, restoration_indices
#
# /usr/local/lib/python3.6/site-packages/allennlp/modules/elmo_lstm.py in _lstm_forward(self, inputs, initial_state)
#     215             forward_output_sequence, forward_state = forward_layer(forward_output_sequence,
#     216                                                                    batch_lengths,
# --> 217                                                                    forward_state)
#     218             backward_output_sequence, backward_state = backward_layer(backward_output_sequence,
#     219                                                                       batch_lengths,
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/site-packages/allennlp/modules/lstm_cell_with_projection.py in forward(self, inputs, batch_lengths, initial_state)
#     176             # Both have shape (batch_size, 4 * cell_size)
#     177             projected_input = self.input_linearity(timestep_input)
# --> 178             projected_state = self.state_linearity(previous_state)
#     179
#     180             # Main LSTM equations using relevant chunks of the big linear
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      53
#      54     def forward(self, input):
# ---> 55         return F.linear(input, self.weight, self.bias)
#      56
#      57     def extra_repr(self):
#
# /usr/local/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#     990     if input.dim() == 2 and bias is not None:
#     991         # fused op is marginally faster
# --> 992         return torch.addmm(bias, input, weight.t())
#     993
#     994     output = input.matmul(weight.t())
#
# KeyboardInterrupt:
